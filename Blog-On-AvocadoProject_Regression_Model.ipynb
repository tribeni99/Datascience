# %% [markdown]
# Dataset Description:
#
# In this study, we will try to see if we can predict the Avocado’s Average Price based on different features.
#
# The variables of the dataset are the following:
#
# Categorical: 'region','type'
#
# Date: 'Date'
#
# Numerical:'No','Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags','Year'
#
# Target:'AveragePrice'

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\tribe\anaconda3\lib\site-packages (5.5.0)
# Requirement already satisfied: six in c:\users\tribe\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tribe\anaconda3\lib\site-packages (from plotly) (8.0.1)

# %%
# !pip install feature_engine
# Out:
# Requirement already satisfied: feature_engine in c:\users\tribe\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (1.20.1)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (0.12.2)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (1.2.4)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (1.0.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (1.6.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tribe\anaconda3\lib\site-packages (from pandas>=1.0.3->feature_engine) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\tribe\anaconda3\lib\site-packages (from pandas>=1.0.3->feature_engine) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\tribe\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.0.3->feature_engine) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\tribe\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->feature_engine) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tribe\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->feature_engine) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\tribe\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature_engine) (0.5.1)

# %%
# !pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in c:\users\tribe\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\tribe\anaconda3\lib\site-packages (from wikipedia) (4.9.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\tribe\anaconda3\lib\site-packages (from wikipedia) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\tribe\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tribe\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\tribe\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tribe\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.12.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tribe\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.2.1)

# %%
# !pip install chart_studio
# Out:
# Requirement already satisfied: chart_studio in c:\users\tribe\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: six in c:\users\tribe\anaconda3\lib\site-packages (from chart_studio) (1.15.0)
# Requirement already satisfied: plotly in c:\users\tribe\anaconda3\lib\site-packages (from chart_studio) (5.5.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\tribe\anaconda3\lib\site-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: requests in c:\users\tribe\anaconda3\lib\site-packages (from chart_studio) (2.25.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tribe\anaconda3\lib\site-packages (from plotly->chart_studio) (8.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tribe\anaconda3\lib\site-packages (from requests->chart_studio) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\tribe\anaconda3\lib\site-packages (from requests->chart_studio) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\tribe\anaconda3\lib\site-packages (from requests->chart_studio) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tribe\anaconda3\lib\site-packages (from requests->chart_studio) (2020.12.5)

# %%
#importing project dependencies:
 
#compute dependency
import numpy as np

#dataframe dependency
import pandas as pd
#Visualization Dependency
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import chart_studio.plotly as py #For World Map
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import plotly.express as px
# stats dependency
from scipy import stats
# feature_engineering dependency
import feature_engine
# from scraping some data
import webbrowser
import wikipedia

import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv("https://raw.githubusercontent.com/tribeni99/Datascience/main/avocado.csv")

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# Exploratory Data Analysis(EDA):

# %%
# Dropping Unnamed: 0 column
df = df.drop('Unnamed: 0', axis=1)

df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# We've dropped the 'Unnamed: 0' column because it is not contributing to the Average Price of the Avocado.

# %%
# Checking the shape of the dataset

df.shape
# Out:
# (18249, 13)

# %% [markdown]
# The dataset content contains 18249 rows and 13 columns after deleting the 'Unnamed: 0' column. It also includes the target column.
# The target column is 'AveragePrice'.

# %%
# Checking for the columns
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %% [markdown]
# Feature Description:
# i)Date: The date of the observation
#
# ii)AveragePrice: Average Price of the avocado. (This is our target column)
#
# iii)Total Volume.
#
# iv)4046: Total number of avocados with PLU 4046 sold
#
# v)4225: Total number of avocados with PLU 4225 sold
#
# vi)4770: Total number of avocados with PLU 4770 sold
#
# vii)Total Bags: Total number of bags.
#
# viii)Small Bags: Number of small sized bags
#
# ix)Large Bags: Number of large sized bags
#
# x)XLarge Bags: Number of xtra large sized bags
#
# xi)type: conventional or organic
#
# xii)year: Year of observation
#
# xiii)region: the city or region of the observation

# %%
# Renaming the columns '4046', '4225', and '4770' to 'PLU_4046', 'PLU_4225', and 'PLU_4770' respectively.
df = df.rename(columns={'4046':'PLU_4046', '4225':'PLU_4225', '4770':'PLU_4770'})

df.head()
# Out:
#          Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  \
# 0  2015-12-27          1.33      64236.62   1036.74   54454.85     48.16
# 1  2015-12-20          1.35      54876.98    674.28   44638.81     58.33
# 2  2015-12-13          0.93     118220.22    794.70  109149.67    130.50
# 3  2015-12-06          1.08      78992.15   1132.00   71976.41     72.58
# 4  2015-11-29          1.28      51039.60    941.48   43838.39     75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
# Checking the data type of the dataset

df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# PLU_4046        float64
# PLU_4225        float64
# PLU_4770        float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# Out of total 13 columns, 9 columns are of float datatype, 1 is of integer datatype and 3 are of object datatype.
#
#
# Float datatype:
# 1. AveragePrice
# 2. Total Volume
# 3. PLU_4046
# 4. PLU_4225
# 5. PLU_4770
# 6. Total Bags
# 7. Small Bags
# 8. Large Bags
# 9. XLarge Bags
#
# Object datatype:
# 1. Date
# 2. type
# 3. region

# %%
# Checking for the missing values in the dataset

df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# PLU_4046        0
# PLU_4225        0
# PLU_4770        0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# There is no missing values in the dataset.
# Now, we're using .info() to get the general ideas about the dataset.

# %%
# Getting general ideas about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   PLU_4046      18249 non-null  float64
#  4   PLU_4225      18249 non-null  float64
#  5   PLU_4770      18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# Observations from the above table:
# 1)There is no null values in the dataset.
#
# 2)9 out of 13 columns are of float datatype.
#
# 3)3 columns are of object datatype.
#
# 4)Only 1 column 'year' is of integer datatype.
#
# 5)The target column 'AveragePrice' is of float datatype.
#
# Now, we're performing feature enginerring on the date column to get the day and month. We're not extracting the year since it is already there in the dataset.

# %%
df['Date']= pd.to_datetime(df['Date'])
df['Month']= df['Date'].dt.month
df['Day']=df['Date'].dt.day

# %%
# Checking the top 5 rows in the dataset to check the changes which we have made.

df.head()
# Out:
#         Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  \
# 0 2015-12-27          1.33      64236.62   1036.74   54454.85     48.16
# 1 2015-12-20          1.35      54876.98    674.28   44638.81     58.33
# 2 2015-12-13          0.93     118220.22    794.70  109149.67    130.50
# 3 2015-12-06          1.08      78992.15   1132.00   71976.41     72.58
# 4 2015-11-29          1.28      51039.60    941.48   43838.39     75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany     12    6
# 4  Albany     11   29

# %% [markdown]
# We can see that two new coulmns are added in the dataset.
# Month column having the value of the month.
# Day column having the value of the day.
# Month:
# 1 denotes January
# 2 denotes February
# 3 denotes March
# 4 denotes April
# 5 denotes May
# 6 denotes June
# 7 denotes July
# 8 denotes August
# 9 denotes September
# 10 denotes October
# 11 denotes November
# 12 denotes December

# %%
# Dropping 'Date' column from the dataset since we've splitted it into year, month and day.

df = df.drop(['Date'], axis = 1)
df.head()
# Out:
#    AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  Total Bags  \
# 0          1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1          1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2          0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3          1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4          1.28      51039.60    941.48   43838.39     75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12   27
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12   20
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12   13
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12    6
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11   29

# %%
# Checking the Average price of the avacado year-wise.
df.groupby('year')['AveragePrice'].mean()
# Out:
# year
# 2015    1.375590
# 2016    1.338640
# 2017    1.515128
# 2018    1.347531
# Name: AveragePrice, dtype: float64

# %% [markdown]
# From the above observation we can say that the avrage price of the avacado was highest in the year 2017 and lowest in the year 2016.

# %%
# Getting the number of Avacado sold in the 4 years type-wise.
df.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %% [markdown]
# The above table shows that in all the years all most equal number of Avocado was sold from both the types.

# %% [markdown]
# Data Visualization:

# %%
# Plotting bar garph to show the distribution of year-wise average price.
sns.barplot(x='year',y='AveragePrice', data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %% [markdown]
# From above graph, we can get the following conclusions:
# In the year 2017 the price of the Avacado was highest.
# In the year 2015 the price was second highest.
# In the 2016 the price of the Avacado was lowest.

# %%
# Plotting graph to show the Average price distribution month wise.
sns.barplot(x='Month',y='AveragePrice', data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %% [markdown]
# From above graph, we can say that:
# i) September and October month have the maximum prices. This may be due to high demand in the month of September and October.
# ii)From the above graph, the trend of pricing is almost same. This shows that the fruit Avocado is in demand always.

# %%
# Plotting graph to show Average Price distribution region wise.
plt.figure(figsize=[35,40])
sns.barplot(x='AveragePrice', y='region', data = df, orient='h')
plt.xticks(fontsize=16)
plt.yticks(fontsize=20)
plt.show()

# %% [markdown]
# i)From the above graph we can say that the average price of ii)Avocado is highest from the region 'Hartford–Springfield'.
# It is lowest in the region 'Houston'.

# %%
# Plotting graph to show the type-wise average price distribution of Avocado
plt.figure(figsize=[14,5])
sns.lineplot(x='year',y='AveragePrice', hue='type', data=df)
plt.show()

# %% [markdown]
# Price of organic avocado is higher than convetional.

# %%
# Plotting graph to show the type-wise average price distribution of Avocado
plt.figure(figsize=[12,8])
sns.lineplot(x='Month',y='AveragePrice', hue='type', data=df)
plt.show()

# %% [markdown]
# i)We can see that the price of organic Avocado is higher than convetional type Avocado.
#
# ii)The above grapgh shows that there is continuous increase in the average price of the Avocado from the May month for both the types.
#
# iii)For organic avacado the peak value of the average price is attended in the month of September and for the conventional type it is in the month of October.
#
# iv)The average price is continuously increasing after the May month till October month for the convetional type Avocado.
#
# v)The average price is continuously increasing after the May month till September month for the organic type Avocado.

# %%
# Plotting the histogram for univariant analysis to check the normal distribution
df.hist(figsize=[18,16], grid=True, layout=(4,4), bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'PLU_4046'}>,
#         <AxesSubplot:title={'center':'PLU_4225'}>],
#        [<AxesSubplot:title={'center':'PLU_4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>,
#         <AxesSubplot:title={'center':'Small Bags'}>,
#         <AxesSubplot:title={'center':'Large Bags'}>],
#        [<AxesSubplot:title={'center':'XLarge Bags'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'Month'}>,
#         <AxesSubplot:title={'center':'Day'}>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# Checking the Variable Summary:

# %%
# Checking for the data description
df.describe()
# Out:
#        AveragePrice  Total Volume      PLU_4046      PLU_4225      PLU_4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      0.939938
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000   2015.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000   2015.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000   2016.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000   2017.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000   2018.000000
#
#               Month           Day
# count  18249.000000  18249.000000
# mean       6.177215     15.662612
# std        3.534130      8.776281
# min        1.000000      1.000000
# 25%        3.000000      8.000000
# 50%        6.000000     16.000000
# 75%        9.000000     23.000000
# max       12.000000     31.000000

# %%
# Showing description using heatmap
plt.figure(figsize=[16,8])
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True, linewidths=0.45, linecolor='white', fmt='f')
plt.title('Variables Summary')
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# Outcomes of the Variable Summary table:
# We're determining the mean, standard deviation, minimum and maximum values of all the columns.
#
# 1.Average Price (Target Column):
# Mean = 1.41
# std = 0.40
# Minimum value = 0.44
# Maximum value = 3.25
#
# 2.Total Value:
# Mean = 850644.01
# std = 3453545.36
# Minimum value = 84.56
# Maximum value = 62505646.52
#
# 3.PLU_4046:
# Mean = 293008.42
# std = 1264989.08
# Minimum value = 0.00
# Maximum value = 22743616.17
#
# 4.PLU_4225:
# Mean = 295154.57
# std = 1204120.40
# Minimum value = 0.00
# Maximum value = 20470572.61
#
# 5.PLU_4770:
# Mean = 22839.74
# std = 107464.07
# Minimum value = 0.00
# Maximum value = 2546439.11

# %% [markdown]
# Checking for the Correlation:

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume  PLU_4046  PLU_4225  PLU_4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# PLU_4046         -0.208317      0.977863  1.000000  0.926110  0.833389
# PLU_4225         -0.172928      0.974181  0.926110  1.000000  0.887855
# PLU_4770         -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# Month             0.162409     -0.024689 -0.025803 -0.022108 -0.033424
# Day               0.027386     -0.009747 -0.010159 -0.012393 -0.009009
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year  \
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.093197
# Total Volume    0.963047    0.967238    0.880640     0.747157  0.017193
# PLU_4046        0.920057    0.925280    0.838645     0.699377  0.003353
# PLU_4225        0.905787    0.916031    0.810015     0.688809 -0.009559
# PLU_4770        0.792314    0.802733    0.698471     0.679861 -0.036531
# Total Bags      1.000000    0.994335    0.943009     0.804233  0.071552
# Small Bags      0.994335    1.000000    0.902589     0.806845  0.063915
# Large Bags      0.943009    0.902589    1.000000     0.710858  0.087891
# XLarge Bags     0.804233    0.806845    0.710858     1.000000  0.081033
# year            0.071552    0.063915    0.087891     0.081033  1.000000
# Month          -0.022724   -0.023126   -0.020187    -0.012969 -0.177050
# Day            -0.004988   -0.003870   -0.008352     0.000319  0.004475
#
#                  Month       Day
# AveragePrice  0.162409  0.027386
# Total Volume -0.024689 -0.009747
# PLU_4046     -0.025803 -0.010159
# PLU_4225     -0.022108 -0.012393
# PLU_4770     -0.033424 -0.009009
# Total Bags   -0.022724 -0.004988
# Small Bags   -0.023126 -0.003870
# Large Bags   -0.020187 -0.008352
# XLarge Bags  -0.012969  0.000319
# year         -0.177050  0.004475
# Month         1.000000  0.010621
# Day           0.010621  1.000000

# %%
# Plotting heatmap for the correlation table

plt.figure(figsize=[22,14])
sns.heatmap(round(df.corr()[1:].transpose(),2), annot=True, linewidths=0.45, linecolor='white', fmt='f')
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)
plt.title('Correlation Table')
plt.show()

# %%
corr_matrix = df.corr()
corr_matrix['AveragePrice'].sort_values(ascending = False)
# Out:
# AveragePrice    1.000000
# Month           0.162409
# year            0.093197
# Day             0.027386
# XLarge Bags    -0.117592
# PLU_4225       -0.172928
# Large Bags     -0.172940
# Small Bags     -0.174730
# Total Bags     -0.177088
# PLU_4770       -0.179446
# Total Volume   -0.192752
# PLU_4046       -0.208317
# Name: AveragePrice, dtype: float64

# %% [markdown]
# Outcome from the correlation:
# Month column has 16% correlation with the target column which can be considered as good bond. Year column has 9% correlation with the target column which can be considered as good bond. 'Day' column has only 2% bond with the target column which can be considered as weak bond. All other columns have very weak bond.
#
# 1)'Month' column has the highest correlation with the target column (16%).
# 2)'PLU_4046' column has the lowest correlation with the target column (-20%).

# %% [markdown]
# LabelEncoding:

# %%
# LabelEncoder on 'type' column

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['type'].drop_duplicates())
le.classes_
df['type'] = le.transform(df['type'])

# %%
# LabelEncoder on 'region' column

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['region'])
le.classes_
df['region'] = le.transform(df['region'])

# %%
# Checking the head of the dataset
df.head()
# Out:
#    AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  Total Bags  \
# 0          1.33      64236.62   1036.74   54454.85     48.16     8696.87
# 1          1.35      54876.98    674.28   44638.81     58.33     9505.56
# 2          0.93     118220.22    794.70  109149.67    130.50     8145.35
# 3          1.08      78992.15   1132.00   71976.41     72.58     5811.16
# 4          1.28      51039.60    941.48   43838.39     75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Month  Day
# 0     8603.62       93.25          0.0     0  2015       0     12   27
# 1     9408.07       97.49          0.0     0  2015       0     12   20
# 2     8042.21      103.14          0.0     0  2015       0     12   13
# 3     5677.40      133.76          0.0     0  2015       0     12    6
# 4     5986.26      197.69          0.0     0  2015       0     11   29

# %%
# Checking the tail of the dataset
df.tail()
# Out:
#        AveragePrice  Total Volume  PLU_4046  PLU_4225  PLU_4770  Total Bags  \
# 18244          1.63      17074.83   2046.96   1529.20      0.00    13498.67
# 18245          1.71      13888.04   1191.70   3431.50      0.00     9264.84
# 18246          1.87      13766.76   1191.92   2452.79    727.94     9394.11
# 18247          1.93      16205.22   1527.63   2981.04    727.01    10969.54
# 18248          1.62      17489.58   2894.77   2356.13    224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  Month  Day
# 18244    13066.82      431.85          0.0     1  2018      53      2    4
# 18245     8940.04      324.80          0.0     1  2018      53      1   28
# 18246     9351.80       42.31          0.0     1  2018      53      1   21
# 18247    10919.54       50.00          0.0     1  2018      53      1   14
# 18248    11988.14       26.01          0.0     1  2018      53      1    7

# %%
#Checking the data types of the columns again
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# PLU_4046        float64
# PLU_4225        float64
# PLU_4770        float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# Month             int64
# Day               int64
# dtype: object

# %% [markdown]
# We can see that the columns having the categorical data is converted to numerical values.

# %% [markdown]
# Checking for the Outliers in the dataset:

# %%
# Plotting boxplot to check the outliers
fig, axs = plt.subplots(14, figsize=[20,18])

plt1 = sns.boxplot(df['AveragePrice'], ax=axs[0])
plt2 = sns.boxplot(df['Total Volume'], ax = axs[1])
plt3 = sns.boxplot(df['PLU_4046'], ax = axs[2])
plt4 = sns.boxplot(df['PLU_4225'], ax=axs[3])
plt5 = sns.boxplot(df['PLU_4770'], ax = axs[4])
plt6 = sns.boxplot(df['Total Bags'], ax= axs[5])
plt7 = sns.boxplot(df['Small Bags'], ax = axs[6])
plt8 = sns.boxplot(df['Large Bags'], ax= axs[7])
plt9 = sns.boxplot(df['XLarge Bags'], ax = axs[8])
plt10 = sns.boxplot(df['type'], ax = axs[9])
plt11 = sns.boxplot(df['year'], ax = axs[10])
plt12 = sns.boxplot(df['region'], ax = axs[11])
plt13 = sns.boxplot(df['Month'], ax =axs[12])
plt14 = sns.boxplot(df['Day'], ax =axs[13])

plt.tight_layout()

# %% [markdown]
# We can see that, outliers are present in the dataset.
#
# i)Columns 'type', 'Year', 'region', 'Month', and 'Day' do not contain outliers.
# ii)All other columns have outliers present.

# %% [markdown]
# Checking if skewness is present in the datset:

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# PLU_4046         8.648220
# PLU_4225         8.942466
# PLU_4770        10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# Month            0.106617
# Day              0.014310
# dtype: float64

# %% [markdown]
# Outcome of Skewness:
# Skewness threshold is taken as +/-0.5. Columns having shewness:
# 1. Total Volume
# 2. PLU_4046
# 3. PLU_4225
# 4. PLU_4770
# 5. Total Bags
# 6. Small Bags
# 7. Large Bags
# 8. XLarge Bags

# %% [markdown]
# All the above mentioned columns has very high skewness.

# %% [markdown]
# Data Cleaning:

# %% [markdown]
# Removing Outliers using zscore technique:

# %%
from scipy.stats import zscore

z = np.abs(zscore(df))
z.shape
# Out:
# (18249, 14)

# %%
thershold = 3
print(np.where (z>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
# Assigning the values to df_new which are less of thershold value and removing the outliers
df_new = df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)

print ('Shape after removing the outliers is ', df_new.shape)
# Out:
# (18249, 14)
# (17651, 14)
# Shape after removing the outliers is  (17651, 14)

# %%
# Checking percentage of data loss:

loss_per = ((18249-17651)/18249)*100
print ('Percentage of Data Lost is: ',loss_per)
# Out:
# Percentage of Data Lost is:  3.276891884486821

# %% [markdown]
# Dividing the dataset in Features and Vector

# %%
x = df_new.drop(['AveragePrice'], axis = 1)
y = df_new['AveragePrice']

# %% [markdown]
# Using power_transform function we'll try to remove the skewness from the dataset.

# %%
from sklearn.preprocessing import power_transform

x = power_transform(x)
x
# Out:
# array([[-0.07532391, -0.65742071,  0.35142978, ..., -2.01058988,
#          1.49138301,  1.22756521],
#        [-0.14749743, -0.77717852,  0.26951276, ..., -2.01058988,
#          1.49138301,  0.53822879],
#        [ 0.20555557, -0.7317763 ,  0.64933326, ..., -2.01058988,
#          1.49138301, -0.21895878],
#        ...,
#        [-0.77527398, -0.61796649, -0.77889327, ...,  1.57828237,
#         -1.64028838,  0.64019459],
#        [-0.70179733, -0.54701087, -0.71637127, ...,  1.57828237,
#         -1.64028838, -0.10529902],
#        [-0.66738095, -0.35967077, -0.79165015, ...,  1.57828237,
#         -1.64028838, -0.9581001 ]])

# %% [markdown]
# StandardScaler:

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x = scaler.fit_transform(x)
x
# Out:
# array([[-0.07532391, -0.65742071,  0.35142978, ..., -2.01058988,
#          1.49138301,  1.22756521],
#        [-0.14749743, -0.77717852,  0.26951276, ..., -2.01058988,
#          1.49138301,  0.53822879],
#        [ 0.20555557, -0.7317763 ,  0.64933326, ..., -2.01058988,
#          1.49138301, -0.21895878],
#        ...,
#        [-0.77527398, -0.61796649, -0.77889327, ...,  1.57828237,
#         -1.64028838,  0.64019459],
#        [-0.70179733, -0.54701087, -0.71637127, ...,  1.57828237,
#         -1.64028838, -0.10529902],
#        [-0.66738095, -0.35967077, -0.79165015, ...,  1.57828237,
#         -1.64028838, -0.9581001 ]])

# %% [markdown]
# Data Preprocessing:

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# Model Training:

# %% [markdown]
# 1. LinearRegression:

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression( fit_intercept = True)

LR.fit(x_train, y_train)
print(f"Linear coefficients : {LR.coef_}")
print(f"Intercept : {LR.intercept_}")
# Out:
# Linear coefficients : [-2.80942792e-01  1.86981012e-02  2.62501338e-01  3.17413409e-02
#  -2.71079140e-01  2.11668540e-01 -3.18778398e-02  1.47427977e-04
#   1.86376058e-01  9.92756385e-02  1.11847071e-02  7.84959193e-02
#   8.90083811e-03]
# Intercept : 1.4070497697935505

# %%
# Predicting the new result

LR_pred = LR.predict(x_test)
LR_pred
# Out:
# array([1.15750837, 1.24289388, 1.12199189, ..., 1.83389538, 1.53242729,
#        1.20363702])

# %% [markdown]
# 2. DecisionTreeRegressor:

# %%
from sklearn.tree import DecisionTreeRegressor #Importing the library

DT = DecisionTreeRegressor()
DT.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Predicting the new result

DT_pred = DT.predict(x_test)
DT_pred
# Out:
# array([1.41, 1.76, 1.17, ..., 2.31, 1.48, 1.14])

# %% [markdown]
# 3. KNeighborsRegressor:

# %%
from sklearn.neighbors import KNeighborsRegressor

KNN = KNeighborsRegressor(n_neighbors=2)
KNN.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
# Predicting the new result

KNN_pred = KNN.predict(x_test)
KNN_pred
# Out:
# array([1.275, 1.74 , 1.185, ..., 1.99 , 1.495, 1.235])

# %% [markdown]
# 4. RandomForestRegressor:

# %%
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor(max_depth=2, random_state=42)

RF.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=42)

# %%
# Predicting the new result

RF_pred = RF.predict(x_test)
RF_pred
# Out:
# array([1.03166999, 1.23691636, 1.17095743, ..., 1.7182269 , 1.17095743,
#        1.03166999])

# %% [markdown]
# Mean Absolute Error:

# %%
from sklearn.metrics import mean_absolute_error

print(' Mean Absolute Error for LinearRegression is ', mean_absolute_error(y_test, LR_pred),
     '\n Mean Absolute Error for DecisionTreeRegressor is ', mean_absolute_error(y_test, DT_pred),
     '\n Mean Absolute Error for KNeighborsRegressor is ', mean_absolute_error(y_test, KNN_pred),
      '\n Mean Absolute Error for RandomForestRegressor is ', mean_absolute_error(y_test, RF_pred))
# Out:
#  Mean Absolute Error for LinearRegression is  0.19831649387015463
#  Mean Absolute Error for DecisionTreeRegressor is  0.12565562163693003
#  Mean Absolute Error for KNeighborsRegressor is  0.12882186349476069
#  Mean Absolute Error for RandomForestRegressor is  0.2238529288951942

# %% [markdown]
# 1.We can see that the Mean Absilute error is least for DecisionTreeRegressor (0.124), so this can be considered as good model.
# 2.Also the Mean Absolute Error for KNeighboursRegressor is (0.126), which is almost equal to the DecisionTreeRegressor. So, let's check for Root Mean Squared Error and R2_Score to decide the best model.

# %% [markdown]
# Root Mean Squared Error

# %%
from sklearn import metrics

rmse_LR = np.sqrt(metrics.mean_squared_error(y_test, LR_pred))
rmse_DT = np.sqrt(metrics.mean_squared_error(y_test, DT_pred))
rmse_KNN = np.sqrt(metrics.mean_squared_error(y_test, KNN_pred))
rmse_RF = np.sqrt(metrics.mean_squared_error(y_test, RF_pred))

print('Root Mean Squared Error for LinearRegression is ', rmse_LR)
print('Root Mean Squared Error for DecisionTreeRegressor is ', rmse_DT)
print('Root Mean Squared Error for KNeighborsRegressor is ', rmse_KNN)
print('Root Mean Squared Error for RandomForestRegressor is ', rmse_RF)
# Out:
# Root Mean Squared Error for LinearRegression is  0.25185126178528594
# Root Mean Squared Error for DecisionTreeRegressor is  0.19141878125177833
# Root Mean Squared Error for KNeighborsRegressor is  0.18047672795811143
# Root Mean Squared Error for RandomForestRegressor is  0.2842115057447561

# %% [markdown]
# From the above observation we can see that the Root Mean Squared Error is least for KNeighborsRegressor. So, we can consider it best among others. Let's check for the R2_Score

# %% [markdown]
# R-Squred:

# %%
from sklearn.metrics import r2_score

print(' R2_Score for LinearRegression is ', r2_score(y_test, LR_pred), '\n R2_Score for DecisionTreeRegressor is ', r2_score(y_test, DT_pred),
      '\n R2_Score for KNeighborsRegressor is ', r2_score(y_test, KNN_pred), '\n R2_Score for RandomForestRegressor is ', r2_score(y_test, RF_pred))
# Out:
#  R2_Score for LinearRegression is  0.570600173507977
#  R2_Score for DecisionTreeRegressor is  0.7519480210815225
#  R2_Score for KNeighborsRegressor is  0.7794962296478138
#  R2_Score for RandomForestRegressor is  0.4531642320568916

# %% [markdown]
# R2_Score closest to 1.0 is considered as best. From the above observations we can see that the best R2_Score is for KNeighborsRegressor (0.79)

# %% [markdown]
# So, as per the final observations we can say that the best model is KNeighborsRegressor.

# %% [markdown]
# Model Saving:

# %%
import pickle
filename = 'Acovado.pkl'
pickle.dump(KNN, open(filename, 'wb'))

# %% [markdown]
# Conclusion:

# %% [markdown]
# Checking the difference between the Original and Pridicted values

# %%
a = np.array(y_test)
predicted = np.array(KNN.predict(x_test))
df_conclusion = pd.DataFrame({"Original":a, "Predicted":predicted}, index=range(len(a)))

df_conclusion
# Out:
#       Original  Predicted
# 0         1.36      1.275
# 1         1.70      1.740
# 2         1.22      1.185
# 3         0.81      0.900
# 4         1.85      1.900
# ...        ...        ...
# 3526      1.79      2.020
# 3527      1.19      1.180
# 3528      2.31      1.990
# 3529      1.55      1.495
# 3530      1.35      1.235
#
# [3531 rows x 2 columns]

# %%
# Plotting graph to show the diffrence between Predicated and Original Values

plt.figure(figsize=(6,6))
plt.scatter(a, predicted, color='darkorange')

p1 = max(max(predicted), max(a))
p2 = min(min(predicted), min(a))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('Original Values', fontsize=10)
plt.ylabel('Predicted Values', fontsize=10)
plt.axis('equal')
plt.show()
