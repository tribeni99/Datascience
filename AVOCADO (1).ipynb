# %% [markdown]
# #AVOCADO PROJECT

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\tribe\anaconda3\lib\site-packages (5.5.0)
# Requirement already satisfied: six in c:\users\tribe\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tribe\anaconda3\lib\site-packages (from plotly) (8.0.1)

# %%
# !pip install chart_studio
# Out:
# Requirement already satisfied: chart_studio in c:\users\tribe\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: six in c:\users\tribe\anaconda3\lib\site-packages (from chart_studio) (1.15.0)
# Requirement already satisfied: plotly in c:\users\tribe\anaconda3\lib\site-packages (from chart_studio) (5.5.0)
# Requirement already satisfied: requests in c:\users\tribe\anaconda3\lib\site-packages (from chart_studio) (2.25.1)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\tribe\anaconda3\lib\site-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tribe\anaconda3\lib\site-packages (from plotly->chart_studio) (8.0.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\tribe\anaconda3\lib\site-packages (from requests->chart_studio) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tribe\anaconda3\lib\site-packages (from requests->chart_studio) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\tribe\anaconda3\lib\site-packages (from requests->chart_studio) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tribe\anaconda3\lib\site-packages (from requests->chart_studio) (2020.12.5)

# %%
# !pip install feature_engine
# Out:
# Requirement already satisfied: feature_engine in c:\users\tribe\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (1.20.1)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (0.24.1)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (0.12.2)
# Requirement already satisfied: pandas>=1.0.3 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (1.2.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\tribe\anaconda3\lib\site-packages (from feature_engine) (1.6.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\tribe\anaconda3\lib\site-packages (from pandas>=1.0.3->feature_engine) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\tribe\anaconda3\lib\site-packages (from pandas>=1.0.3->feature_engine) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\tribe\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.0.3->feature_engine) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tribe\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->feature_engine) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\tribe\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->feature_engine) (1.0.1)
# Requirement already satisfied: patsy>=0.5 in c:\users\tribe\anaconda3\lib\site-packages (from statsmodels>=0.11.1->feature_engine) (0.5.1)

# %%
# !pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in c:\users\tribe\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\tribe\anaconda3\lib\site-packages (from wikipedia) (2.25.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\tribe\anaconda3\lib\site-packages (from wikipedia) (4.9.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tribe\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\tribe\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tribe\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\tribe\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tribe\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.2.1)

# %%
#importing project dependencies:
 
#compute dependency
import numpy as np

#dataframe dependency
import pandas as pd
#Visualization Dependency
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import chart_studio.plotly as py #For World Map
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import plotly.express as px
# stats dependency
from scipy import stats
# feature_engineering dependency
import feature_engine
# from scraping some data
import webbrowser
import wikipedia

import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv("https://raw.githubusercontent.com/tribeni99/Datascience/main/avocado.csv")

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.describe(include='all')
# Out:
#           Unnamed: 0        Date  AveragePrice  Total Volume          4046  \
# count   18249.000000       18249  18249.000000  1.824900e+04  1.824900e+04
# unique           NaN         169           NaN           NaN           NaN
# top              NaN  2015-04-05           NaN           NaN           NaN
# freq             NaN         108           NaN           NaN           NaN
# mean       24.232232         NaN      1.405978  8.506440e+05  2.930084e+05
# std        15.481045         NaN      0.402677  3.453545e+06  1.264989e+06
# min         0.000000         NaN      0.440000  8.456000e+01  0.000000e+00
# 25%        10.000000         NaN      1.100000  1.083858e+04  8.540700e+02
# 50%        24.000000         NaN      1.370000  1.073768e+05  8.645300e+03
# 75%        38.000000         NaN      1.660000  4.329623e+05  1.110202e+05
# max        52.000000         NaN      3.250000  6.250565e+07  2.274362e+07
#
#                 4225          4770    Total Bags    Small Bags    Large Bags  \
# count   1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    2.951546e+05  2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04
# std     1.204120e+06  1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     3.008780e+03  0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02
# 50%     2.906102e+04  1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03
# 75%     1.502069e+05  6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04
# max     2.047057e+07  2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06
#
#           XLarge Bags          type          year   region
# count    18249.000000         18249  18249.000000    18249
# unique            NaN             2           NaN       54
# top               NaN  conventional           NaN  StLouis
# freq              NaN          9126           NaN      338
# mean      3106.426507           NaN   2016.147899      NaN
# std      17692.894652           NaN      0.939938      NaN
# min          0.000000           NaN   2015.000000      NaN
# 25%          0.000000           NaN   2015.000000      NaN
# 50%          0.000000           NaN   2016.000000      NaN
# 75%        132.500000           NaN   2017.000000      NaN
# max     551693.650000           NaN   2018.000000      NaN

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df.sample(5)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 10176          10  2015-10-18          2.26       2167.37  1601.22      44.61
# 10365          43  2015-03-01          1.65       1510.75     0.00    1077.97
# 736             8  2015-11-01          0.91     205592.10  3731.64  147281.28
# 14098          33  2016-05-08          1.37      22751.54  1313.14   11595.98
# 13804          51  2016-01-03          1.50      38955.86  3092.05   15012.16
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 10176    14.87      506.67      506.67        0.00         0.00       organic
# 10365     0.00      432.78      213.33      219.45         0.00       organic
# 736    8605.43    45973.75    43392.69     1757.12       823.94  conventional
# 14098     0.00     9842.42     9788.41       54.01         0.00       organic
# 13804  2689.51    18162.14     7903.68    10258.46         0.00       organic
#
#        year        region
# 10176  2015  Jacksonville
# 10365  2015    Louisville
# 736    2015   GrandRapids
# 14098  2016      SanDiego
# 13804  2016        Plains

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Unnamed: 0    0.041752   -0.002219    0.000347   -0.009196    -0.011546
# AveragePrice -0.179446   -0.177088   -0.174730   -0.172940    -0.117592
# Total Volume  0.872202    0.963047    0.967238    0.880640     0.747157
# 4046          0.833389    0.920057    0.925280    0.838645     0.699377
# 4225          0.887855    0.905787    0.916031    0.810015     0.688809
# 4770          1.000000    0.792314    0.802733    0.698471     0.679861
# Total Bags    0.792314    1.000000    0.994335    0.943009     0.804233
# Small Bags    0.802733    0.994335    1.000000    0.902589     0.806845
# Large Bags    0.698471    0.943009    0.902589    1.000000     0.710858
# XLarge Bags   0.679861    0.804233    0.806845    0.710858     1.000000
# year         -0.036531    0.071552    0.063915    0.087891     0.081033
#
#                   year
# Unnamed: 0   -0.171667
# AveragePrice  0.093197
# Total Volume  0.017193
# 4046          0.003353
# 4225         -0.009559
# 4770         -0.036531
# Total Bags    0.071552
# Small Bags    0.063915
# Large Bags    0.087891
# XLarge Bags   0.081033
# year          1.000000

# %%
def fig_this_size(x,y):
    
    
    return plt.figure(figsize=(x,y))

# %%
fig_this_size(12,10)
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
fig = fig_this_size(16,4)

fig.add_subplot(121)
sns.distplot(df.AveragePrice)

fig.add_subplot(122)
plt.hist(df.AveragePrice);

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
df.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %%
df.skew()
# Out:
# Unnamed: 0       0.108334
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %%
df['Year'], df['Month'], df['Day'] = df['Date'].str.split('-').str
df.drop(columns=['Date','year'], inplace=True)
df
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0         8696.87     8603.62       93.25          0.0  conventional
# 1         9505.56     9408.07       97.49          0.0  conventional
# 2         8145.35     8042.21      103.14          0.0  conventional
# 3         5811.16     5677.40      133.76          0.0  conventional
# 4         6183.95     5986.26      197.69          0.0  conventional
# ...           ...         ...         ...          ...           ...
# 18244    13498.67    13066.82      431.85          0.0       organic
# 18245     9264.84     8940.04      324.80          0.0       organic
# 18246     9394.11     9351.80       42.31          0.0       organic
# 18247    10969.54    10919.54       50.00          0.0       organic
# 18248    12014.15    11988.14       26.01          0.0       organic
#
#                  region  Year Month Day
# 0                Albany  2015    12  27
# 1                Albany  2015    12  20
# 2                Albany  2015    12  13
# 3                Albany  2015    12  06
# 4                Albany  2015    11  29
# ...                 ...   ...   ...  ..
# 18244  WestTexNewMexico  2018    02  04
# 18245  WestTexNewMexico  2018    01  28
# 18246  WestTexNewMexico  2018    01  21
# 18247  WestTexNewMexico  2018    01  14
# 18248  WestTexNewMexico  2018    01  07
#
# [18249 rows x 15 columns]

# %%
df['Year']=df['Year'].astype(int)
df['Month']=df['Month'].astype(int)
df['Date']=df['Day'].astype(int)
df.drop(columns=['Day'], inplace=True)
df
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0               0          1.33      64236.62  1036.74   54454.85   48.16
# 1               1          1.35      54876.98   674.28   44638.81   58.33
# 2               2          0.93     118220.22   794.70  109149.67  130.50
# 3               3          1.08      78992.15  1132.00   71976.41   72.58
# 4               4          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244           7          1.63      17074.83  2046.96    1529.20    0.00
# 18245           8          1.71      13888.04  1191.70    3431.50    0.00
# 18246           9          1.87      13766.76  1191.92    2452.79  727.94
# 18247          10          1.93      16205.22  1527.63    2981.04  727.01
# 18248          11          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0         8696.87     8603.62       93.25          0.0  conventional
# 1         9505.56     9408.07       97.49          0.0  conventional
# 2         8145.35     8042.21      103.14          0.0  conventional
# 3         5811.16     5677.40      133.76          0.0  conventional
# 4         6183.95     5986.26      197.69          0.0  conventional
# ...           ...         ...         ...          ...           ...
# 18244    13498.67    13066.82      431.85          0.0       organic
# 18245     9264.84     8940.04      324.80          0.0       organic
# 18246     9394.11     9351.80       42.31          0.0       organic
# 18247    10969.54    10919.54       50.00          0.0       organic
# 18248    12014.15    11988.14       26.01          0.0       organic
#
#                  region  Year  Month  Date
# 0                Albany  2015     12    27
# 1                Albany  2015     12    20
# 2                Albany  2015     12    13
# 3                Albany  2015     12     6
# 4                Albany  2015     11    29
# ...                 ...   ...    ...   ...
# 18244  WestTexNewMexico  2018      2     4
# 18245  WestTexNewMexico  2018      1    28
# 18246  WestTexNewMexico  2018      1    21
# 18247  WestTexNewMexico  2018      1    14
# 18248  WestTexNewMexico  2018      1     7
#
# [18249 rows x 15 columns]

# %%
print(df['type'].value_counts())
sns.countplot(x='type', data=df, palette="plasma")
plt.show()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# There are two types of columns conventional and organic.

# %%
print(df['Year'].value_counts())
sns.countplot(x='Year', data=df)
plt.show()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: Year, dtype: int64

# %% [markdown]
# In 2018 data is very less as compared to the other three years.

# %%
print(df['Month'].value_counts())
plt.figure(figsize=(8,5))
sns.countplot(x='Month', data=df, palette="cubehelix")
plt.show()
# Out:
# 1     1944
# 3     1836
# 2     1728
# 5     1512
# 7     1512
# 10    1512
# 4     1404
# 8     1404
# 11    1404
# 12    1403
# 9     1296
# 6     1294
# Name: Month, dtype: int64

# %% [markdown]
# In the dataset June is the least and January is the highest percentage.

# %%
print(df['Date'].value_counts())
plt.figure(figsize=(20,15))
sns.countplot(x='Date', data=df, palette="turbo")
plt.show()
# Out:
# 11    756
# 4     756
# 18    755
# 25    755
# 8     648
# 12    648
# 24    648
# 1     648
# 26    648
# 22    648
# 5     648
# 19    648
# 3     648
# 15    648
# 17    648
# 10    648
# 27    540
# 28    540
# 7     540
# 14    540
# 29    540
# 21    540
# 20    540
# 13    540
# 6     539
# 30    432
# 16    432
# 9     432
# 23    432
# 2     432
# 31    432
# Name: Date, dtype: int64

# %% [markdown]
# The highest value is 11 and 4, lowest are 30,16,9,23.

# %%
print(df['region'].value_counts())
plt.figure(figsize=(15,6))
sns.countplot(df['region'], data=df)
plt.title(f'Count Plot for regions')
plt.xticks(rotation=90)
plt.show()
# Out:
# StLouis                338
# MiamiFtLauderdale      338
# Philadelphia           338
# Syracuse               338
# Midsouth               338
# DallasFtWorth          338
# NewOrleansMobile       338
# West                   338
# Orlando                338
# Columbus               338
# RichmondNorfolk        338
# Houston                338
# Charlotte              338
# LosAngeles             338
# Nashville              338
# Boston                 338
# Louisville             338
# SouthCarolina          338
# HarrisburgScranton     338
# NewYork                338
# Detroit                338
# Spokane                338
# Boise                  338
# Northeast              338
# HartfordSpringfield    338
# Albany                 338
# CincinnatiDayton       338
# Southeast              338
# Plains                 338
# Sacramento             338
# Denver                 338
# GreatLakes             338
# SanFrancisco           338
# RaleighGreensboro      338
# BaltimoreWashington    338
# Atlanta                338
# California             338
# Indianapolis           338
# Roanoke                338
# NorthernNewEngland     338
# SouthCentral           338
# GrandRapids            338
# Jacksonville           338
# Chicago                338
# SanDiego               338
# Seattle                338
# TotalUS                338
# Portland               338
# PhoenixTucson          338
# Tampa                  338
# LasVegas               338
# BuffaloRochester       338
# Pittsburgh             338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %% [markdown]
# WestTextNewMexico has lowest as compare to others.

# %%
plt.figure(figsize=(15,10))
sns.catplot(x="Year", y="AveragePrice", hue="type", data=df, palette="seismic")
plt.show()

# %% [markdown]
# In the above categorical plot we see the average price information as per year and how conventional and organic types.

# %%
plt.figure(figsize=(15,10))
sns.catplot(x="type", y="Total Volume", hue="Year", kind="bar", data=df, palette="hot")
plt.show()

# %% [markdown]
# In the above bar plot we see that the Total Volumn for conventional type were high in all 4 years when compared to it's organic counterparts.

# %%
plt.figure(figsize=(15,10))
sns.catplot(x="type", y="Total Bags", hue="Year", data=df, kind="bar", palette="hsv")
plt.show()

# %% [markdown]
# In the above bar plot we see that since the Total Volume was always high for conventional types being sold therefore the usage of bags was higher for conventional types over the organic ones. Therefore we see that Total Bags is high adn specially highest in 2018 for conventional avacados just like the Total Volume that was sold being directly proportional with each other.

# %%
region = df.groupby('region')['Total Volume'].sum().sort_values(ascending=False).reset_index()
plt.figure(figsize=(15,13))
sns.barplot(x=region["Total Volume"], y=region["region"], data=df, palette="Set3")
plt.show()

# %% [markdown]
# In the above bar plot we can see a sorted number of Total Volume of avacados sold from each and every region. Therefore when compared to the Total US area per region values are lesser but we can see tha major contributors in region are West, California, South Central, North East, South East, Great Lakes, Mid South, Los Angeles, Plains, New York and so forth.

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='AveragePrice', y='region', hue='type', data=df, palette="cubehelix_r")
plt.show()

# %% [markdown]
# In the above scatter plot that holds data between Region vs Average Price we can see clearly how organic avacados are priced way higher than it's conventional counterparts in each and every region.

# %%
plt.figure(figsize=(15,10))
sns.stripplot(x='region', y='AveragePrice', hue="Year", data=df, palette="turbo")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# In the above strip plot we see the Average Price of avacodos over all the regions in all 4 years. We can see that in years 2016 and 2017 the average prices were way higher than in the years 2015 and 2018.

# %%
upper_triangle = np.triu(df.corr())
plt.figure(figsize=(17,12))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="inferno", mask=upper_triangle)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# We generated a pairplot for all our features and label column but it has turned out to be very tiny to be visible properly hence we will take help of a heatmap and understand the correlation details.
#
# From the above heatmap we undertand that there is multicolinearity present in our feature columns. There are 2 types of correlation namely Positive correlation when a correlation of +1 indicates a perfect positive correlation, meaning that both variables move in the same direction together and Negative correlation when a correlation of –1 indicates a perfect negative correlation, meaning that as one variable goes up, the other goes down.
#
# Here we notice that columns PLU 4046, PLU 4225 and PLU 4770 are all product codes that comprise the Total Volume. Similarly, the columns Small Bags, Large Bags, Extra Large Bags all comprise the Total Bags. Therefore to sort out the multicolinearity concern we can drop the unnecessary columns.

# %%
df.drop(["4046", "4225", "4770", "Small Bags", "Large Bags", "XLarge Bags"], axis=1, inplace=True)

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
oe = OrdinalEncoder()
df['region']=oe.fit_transform(df['region'].values.reshape(-1,1))
df['type']=oe.fit_transform(df['type'].values.reshape(-1,1))
df
# Out:
#        Unnamed: 0  AveragePrice  Total Volume  Total Bags  type  region  Year  \
# 0               0          1.33      64236.62     8696.87   0.0     0.0  2015
# 1               1          1.35      54876.98     9505.56   0.0     0.0  2015
# 2               2          0.93     118220.22     8145.35   0.0     0.0  2015
# 3               3          1.08      78992.15     5811.16   0.0     0.0  2015
# 4               4          1.28      51039.60     6183.95   0.0     0.0  2015
# ...           ...           ...           ...         ...   ...     ...   ...
# 18244           7          1.63      17074.83    13498.67   1.0    53.0  2018
# 18245           8          1.71      13888.04     9264.84   1.0    53.0  2018
# 18246           9          1.87      13766.76     9394.11   1.0    53.0  2018
# 18247          10          1.93      16205.22    10969.54   1.0    53.0  2018
# 18248          11          1.62      17489.58    12014.15   1.0    53.0  2018
#
#        Month  Date
# 0         12    27
# 1         12    20
# 2         12    13
# 3         12     6
# 4         11    29
# ...      ...   ...
# 18244      2     4
# 18245      1    28
# 18246      1    21
# 18247      1    14
# 18248      1     7
#
# [18249 rows x 9 columns]

# %%
fig, ax = plt.subplots(ncols=7, nrows=1, figsize=(12,7))
index = 0
features = df.drop("AveragePrice", axis=1)
ax = ax.flatten()
for col, value in features.items():
    sns.boxplot(y=col, data=df, ax=ax[index], palette="plasma")
    index += 1
plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-bf5f6cf8322f> in <module>
#       4 ax = ax.flatten()
#       5 for col, value in features.items():
# ----> 6     sns.boxplot(y=col, data=df, ax=ax[index], palette="plasma")
#       7     index += 1
#       8 plt.tight_layout(pad=0.1, w_pad=0.5, h_pad=1.0)
#
# IndexError: index 7 is out of bounds for axis 0 with size 7

# %% [markdown]
# In the above box plot we see some outliers present in our feature columns "Total Volume" and "Total Bags" so we shall treat it with the usage of zscore.

# %%
from scipy.stats import zscore

# %%
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy()
# Out:
# Shape of the dataframe before removing outliers:  (18249, 9)
# Shape of the dataframe after removing outliers:  (17931, 9)
# Percentage of data loss post outlier removal:  1.7425612362321221

# %%
plt.figure(figsize=(12,7))
sns.distplot(x=df["Total Volume"], hist=False, color="y", kde_kws={"shade": True})
plt.show()

# %% [markdown]
# We see right skewness in the column Total Volume that had outliers too.

# %%
plt.figure(figsize=(12,7))
sns.distplot(x=df["Total Bags"], hist=False, color="y", kde_kws={"shade": True})
plt.show()

# %% [markdown]
# We see right skewness in the column Total Volume that had outliers too.

# %%
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# Unnamed: 0      0.101620
# AveragePrice    0.388855
# Total Volume   -0.024234
# Total Bags     -0.334742
# type           -0.005912
# region          0.014808
# Year            0.225227
# Month           0.114771
# Date            0.014381
# dtype: float64

# %%
X = df.drop('AveragePrice', axis=1)
Y = df['AveragePrice']

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.head(10)
# Out:
#    Unnamed: 0  Total Volume  Total Bags     type    region      Year  \
# 0   -1.566237     -0.090582   -0.493196 -1.00296 -1.694204 -1.215795
# 1   -1.501725     -0.161393   -0.452528 -1.00296 -1.694204 -1.215795
# 2   -1.437213      0.183695   -0.523161 -1.00296 -1.694204 -1.215795
# 3   -1.372700      0.002395   -0.677598 -1.00296 -1.694204 -1.215795
# 4   -1.308188     -0.193989   -0.649161 -1.00296 -1.694204 -1.215795
# 5   -1.243676     -0.152446   -0.613603 -1.00296 -1.694204 -1.215795
# 6   -1.179163      0.027100   -0.513521 -1.00296 -1.694204 -1.215795
# 7   -1.114651      0.148946   -0.603766 -1.00296 -1.694204 -1.215795
# 8   -1.050139      0.107584   -0.369872 -1.00296 -1.694204 -1.215795
# 9   -0.985627     -0.024906   -0.496942 -1.00296 -1.694204 -1.215795
#
#       Month      Date
# 0  1.650340  1.291781
# 1  1.650340  0.493909
# 2  1.650340 -0.303964
# 3  1.650340 -1.101837
# 4  1.367566  1.519745
# 5  1.367566  0.721872
# 6  1.367566 -0.076001
# 7  1.367566 -0.873873
# 8  1.367566 -1.671746
# 9  1.084793  1.063818

# %%
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train, Y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(Y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.5067232076963768 on Random State 144

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=144)

# %%
# Regression Model Function

def reg(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=708)
    
    # Training the model
    model.fit(X_train, Y_train)
    
    # Predicting Y_test
    pred = model.predict(X_test)
    
    # RMSE - a lower RMSE score is better than a higher one
    rmse = mean_squared_error(Y_test, pred, squared=False)
    print("RMSE Score is:", rmse)
    
    # R2 score
    r2 = r2_score(Y_test, pred, multioutput='variance_weighted')*100
    print("R2 Score is:", r2)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    # Result of r2 score minus cv score
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %%
# Linear Regression Model

model=LinearRegression()
reg(model, X, Y)
# Out:
# RMSE Score is: 0.2826539649490082
# R2 Score is: 48.52670793782554
# Cross Validation Score: 14.180521485507953
# R2 Score - Cross Validation Score is 34.34618645231759

# %%
# Ridge Regression

model=Ridge(alpha=1e-2, normalize=True)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.2831165512752812
# R2 Score is: 48.358089568897064
# Cross Validation Score: 14.370703391375475
# R2 Score - Cross Validation Score is 33.987386177521586

# %%
# Lasso Regression

model=Lasso(alpha=1e-2, normalize=True, max_iter=1e5)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.39412850641568486
# R2 Score is: -0.08004140738024912
# Cross Validation Score: -116.71934809126752
# R2 Score - Cross Validation Score is 116.63930668388727

# %%
# Support Vector Regression

model=SVR(C=1.0, epsilon=0.2, kernel='poly', gamma='auto')
reg(model, X, Y)
# Out:
# RMSE Score is: 0.25642938781691366
# R2 Score is: 57.63498422841267
# Cross Validation Score: -57.40961002308778
# R2 Score - Cross Validation Score is 115.04459425150046

# %%
# Decision Tree Regressor

model=DecisionTreeRegressor(criterion="poisson", random_state=111)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.3417297329033748
# R2 Score is: 24.76198733643683
# Cross Validation Score: -147.89722260338294
# R2 Score - Cross Validation Score is 172.6592099398198

# %%
# Random Forest Regressor

model=RandomForestRegressor(max_depth=2, max_features="sqrt")
reg(model, X, Y)
# Out:
# RMSE Score is: 0.3009569671210542
# R2 Score is: 41.64466257451617
# Cross Validation Score: -18.136303230925204
# R2 Score - Cross Validation Score is 59.78096580544137

# %%
# K Neighbors Regressor

KNeighborsRegressor(n_neighbors=2, algorithm='kd_tree')
reg(model, X, Y)
# Out:
# RMSE Score is: 0.3016158697467764
# R2 Score is: 41.38886137897285
# Cross Validation Score: -20.386695651197027
# R2 Score - Cross Validation Score is 61.77555703016988

# %%
# Gradient Boosting Regressor

model=GradientBoostingRegressor(loss='quantile', n_estimators=200, max_depth=5)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.2772810681907214
# R2 Score is: 50.46499419916746
# Cross Validation Score: -21.125023410214823
# R2 Score - Cross Validation Score is 71.59001760938227

# %%
# Ada Boost Regressor

model=AdaBoostRegressor(n_estimators=300, learning_rate=1.05, random_state=42)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.27020600483936646
# R2 Score is: 52.960599983547226
# Cross Validation Score: -2.717405466386207
# R2 Score - Cross Validation Score is 55.67800544993343

# %%
# Extra Trees Regressor

model=ExtraTreesRegressor(n_estimators=200, max_features='sqrt', n_jobs=6)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.20418033984148115
# R2 Score is: 73.14039473013656
# Cross Validation Score: 14.737988760456927
# R2 Score - Cross Validation Score is 58.402405969679634

# %%
param_dict = {
 'max_depth': [10, 30, 50, 70, None],
 'max_features': ['auto', 'sqrt'],
 'min_samples_leaf': [1, 2, 4],
 'min_samples_split': [2, 5, 10],
 'n_estimators': [100.,200, 400, 600]}

# %%
# fitting the model
gs_model = GridSearchCV(RandomForestRegressor(),param_grid=param_dict,cv=5,verbose=3)
gs_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.1s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   9.3s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   7.8s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   7.4s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   7.5s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   7.4s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  11.2s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  11.9s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  11.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  11.2s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  11.3s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   7.3s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   7.5s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   7.2s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   7.5s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   7.2s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  11.1s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  11.1s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  11.5s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  12.5s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  12.6s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.2s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.2s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   7.3s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   7.2s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   7.3s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   7.1s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   7.4s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  11.8s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  11.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  12.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  10.8s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  10.9s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   7.5s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   7.3s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   7.4s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   7.3s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   7.5s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  11.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  11.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  11.1s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  10.9s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  11.1s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   7.4s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   8.7s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  10.3s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  13.3s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  14.3s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  19.7s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  13.9s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  15.8s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  14.3s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  11.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   7.4s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   7.3s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   7.1s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   7.1s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   7.4s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  11.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  10.8s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  11.6s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  12.1s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  10.9s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   7.2s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   7.3s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   7.2s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   7.2s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   7.3s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  10.9s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  10.8s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  10.9s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  10.9s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  10.8s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   7.1s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   7.2s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   7.3s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   7.1s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   7.3s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  10.9s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  10.9s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  10.9s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  11.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  10.8s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   7.3s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   7.1s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   7.3s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   7.1s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   7.4s
# [CV 1/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  10.8s
# [CV 2/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  10.9s
# [CV 3/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  10.9s
# [CV 4/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  11.0s
# [CV 5/5] END max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  10.9s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   3.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   3.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   3.8s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   3.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=   4.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   3.9s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.4s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   2.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.7s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.8s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.8s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   2.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   2.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   3.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   3.8s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.3s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   2.5s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   2.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.7s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.4s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.4s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   2.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   3.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   3.8s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   3.8s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   3.6s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   3.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   3.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   3.6s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   2.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   3.6s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   3.6s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   3.6s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   3.9s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   3.7s
# [CV 1/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   5.8s
# [CV 2/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   6.1s
# [CV 3/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   5.9s
# [CV 4/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   6.1s
# [CV 5/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   6.0s
# [CV 1/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  12.0s
# [CV 2/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  11.8s
# [CV 3/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  11.8s
# [CV 4/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  11.8s
# [CV 5/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  11.9s
# [CV 1/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  17.8s
# [CV 2/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  18.1s
# [CV 3/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  17.7s
# [CV 4/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  18.0s
# [CV 5/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  17.7s
# [CV 1/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# ...
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   5.5s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   5.2s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   5.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   5.2s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   5.1s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   4.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   4.2s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=   4.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   7.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   7.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   7.5s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   8.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   8.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.9s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   5.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   4.9s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   4.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   4.1s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=   4.3s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   6.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   6.9s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   6.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   7.1s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   7.6s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.3s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.7s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   2.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   4.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   3.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   3.8s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   3.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=   3.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   6.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   7.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   7.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   6.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=   5.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   3.9s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   3.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   3.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   3.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=   3.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   5.2s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   5.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   5.3s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   5.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=   5.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.8s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.7s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   3.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   3.6s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   3.7s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   3.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=   3.4s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   6.1s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   5.3s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   5.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   5.2s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=   5.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100.0; total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.7s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.6s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   3.6s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   3.3s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   3.4s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   3.7s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=   3.3s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   5.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   5.0s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   5.1s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   5.3s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=   5.0s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [10, 30, 50, 70, None],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100.0, 200, 400, 600]},
#              verbose=3)

# %%
gs_model.best_estimator_
# Out:
# RandomForestRegressor(max_depth=50, n_estimators=600)

# %%
gs_model.best_score_
# Out:
# 0.8578484958032047

# %%
gs_model.best_params_
# Out:
# {'max_depth': 50,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 600}

# %%
gs_model.cv_results_
# Out:
# {'mean_fit_time': array([3.94597054e-03, 4.03974590e+00, 7.85762143e+00, 1.12436728e+01,
#         2.46849060e-03, 3.65299640e+00, 7.31359997e+00, 1.16674190e+01,
#         2.97050476e-03, 3.93302712e+00, 7.24187384e+00, 1.12158556e+01,
#         4.16035652e-03, 3.69654613e+00, 7.36428657e+00, 1.09597886e+01,
#         2.06556320e-03, 3.66710711e+00, 1.06541384e+01, 1.47998904e+01,
#         5.41024208e-03, 3.70579262e+00, 7.22863393e+00, 1.11900875e+01,
#         4.16073799e-03, 3.64734406e+00, 7.20588431e+00, 1.07750634e+01,
#         2.18834877e-03, 3.65400810e+00, 7.18960209e+00, 1.08113917e+01,
#         2.51388550e-03, 3.60879049e+00, 7.19646621e+00, 1.08083317e+01,
#         1.97596550e-03, 1.26869249e+00, 2.50094266e+00, 3.79196372e+00,
#         3.17296982e-03, 1.21185398e+00, 2.46782904e+00, 3.65906301e+00,
#         4.92229462e-03, 1.19172792e+00, 2.40431285e+00, 4.29137330e+00,
#         3.30295563e-03, 1.23084621e+00, 2.46560073e+00, 3.69473295e+00,
#         4.06360626e-03, 1.20845342e+00, 2.54216766e+00, 3.64828329e+00,
#         5.13248444e-03, 1.22700810e+00, 2.41843576e+00, 3.62245355e+00,
#         4.86197472e-03, 1.20663171e+00, 2.41996107e+00, 3.60600858e+00,
#         2.44383812e-03, 1.22590704e+00, 2.38306952e+00, 3.62323327e+00,
#         4.40297127e-03, 1.17643538e+00, 2.43712468e+00, 3.62197561e+00,
#         2.34508514e-03, 5.97202377e+00, 1.17216868e+01, 1.76121039e+01,
#         2.27627754e-03, 5.06823659e+00, 1.01495405e+01, 1.52409223e+01,
#         2.18019485e-03, 4.49705749e+00, 9.08844805e+00, 1.41135819e+01,
#         4.17237282e-03, 4.99060488e+00, 1.00533128e+01, 1.60076644e+01,
#          45,  40, 279,  71,  63,  61, 326,  93,  82,  75, 322,  96,  77,
#          87, 318, 105, 103, 104, 314, 146, 139, 138, 311, 159, 151, 153,
#         307, 184, 187, 190, 332, 162, 160, 161, 358, 182, 174, 179, 356,
#         199, 206, 203, 352, 229, 227, 213, 348, 228, 216, 221, 344, 232,
#         237, 238, 342,  10,   4,   6, 338,  20,  18,  21, 334,  59,  50,
#          54, 331,  36,  28,  32, 275,  47,  42,  39, 273,  70,  65,  69,
#         272,  95,  90,  76, 271,  85,  84,  73, 276, 107,  97,  99, 280,
#         147, 140, 143, 302, 148, 157, 149, 298, 194, 192, 188, 296, 178,
#         163, 168, 294, 183, 173, 175, 293, 204, 200, 202, 289, 222, 220,
#         210, 285, 223, 208, 209, 281, 243, 239, 236])}

# %%
gs_model.score(X_train,Y_train)
# Out:
# 0.982961799202581

# %%
gs_model.score( X_test, Y_test )
# Out:
# 0.8872457176200047

# %%
import joblib
joblib.dump(gs_model,'price_model_reg.pkl')
# Out:
# ['price_model_reg.pkl']

# %%
X = df.drop('AveragePrice', axis=1)
Y = df['AveragePrice']

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.head(10)
# Out:
#    Unnamed: 0  Total Volume  Total Bags     type    region      Year  \
# 0   -1.566237     -0.090582   -0.493196 -1.00296 -1.694204 -1.215795
# 1   -1.501725     -0.161393   -0.452528 -1.00296 -1.694204 -1.215795
# 2   -1.437213      0.183695   -0.523161 -1.00296 -1.694204 -1.215795
# 3   -1.372700      0.002395   -0.677598 -1.00296 -1.694204 -1.215795
# 4   -1.308188     -0.193989   -0.649161 -1.00296 -1.694204 -1.215795
# 5   -1.243676     -0.152446   -0.613603 -1.00296 -1.694204 -1.215795
# 6   -1.179163      0.027100   -0.513521 -1.00296 -1.694204 -1.215795
# 7   -1.114651      0.148946   -0.603766 -1.00296 -1.694204 -1.215795
# 8   -1.050139      0.107584   -0.369872 -1.00296 -1.694204 -1.215795
# 9   -0.985627     -0.024906   -0.496942 -1.00296 -1.694204 -1.215795
#
#       Month      Date
# 0  1.650340  1.291781
# 1  1.650340  0.493909
# 2  1.650340 -0.303964
# 3  1.650340 -1.101837
# 4  1.367566  1.519745
# 5  1.367566  0.721872
# 6  1.367566 -0.076001
# 7  1.367566 -0.873873
# 8  1.367566 -1.671746
# 9  1.084793  1.063818

# %% [markdown]
# #Finding best random state for building Regression Models

# %%
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train, Y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(Y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.5067232076963768 on Random State 144

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=144)

# %% [markdown]
# #Machine Learning Model for Regression with Evaluation Metrics

# %%
# Regression Model Function

def reg(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=708)
    
    # Training the model
    model.fit(X_train, Y_train)
    
    # Predicting Y_test
    pred = model.predict(X_test)
    
    # RMSE - a lower RMSE score is better than a higher one
    rmse = mean_squared_error(Y_test, pred, squared=False)
    print("RMSE Score is:", rmse)
    
    # R2 score
    r2 = r2_score(Y_test, pred, multioutput='variance_weighted')*100
    print("R2 Score is:", r2)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    # Result of r2 score minus cv score
    result = r2 - cv_score
    print("R2 Score - Cross Validation Score is", result)

# %%
# Linear Regression Model

model=LinearRegression()
reg(model, X, Y)
# Out:
# RMSE Score is: 0.2826539649490082
# R2 Score is: 48.52670793782554
# Cross Validation Score: 14.180521485507953
# R2 Score - Cross Validation Score is 34.34618645231759

# %%
# Ridge Regression

model=Ridge(alpha=1e-2, normalize=True)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.2831165512752812
# R2 Score is: 48.358089568897064
# Cross Validation Score: 14.370703391375475
# R2 Score - Cross Validation Score is 33.987386177521586

# %%
# Lasso Regression

model=Lasso(alpha=1e-2, normalize=True, max_iter=1e5)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.39412850641568486
# R2 Score is: -0.08004140738024912
# Cross Validation Score: -116.71934809126752
# R2 Score - Cross Validation Score is 116.63930668388727

# %%
# Support Vector Regression

model=SVR(C=1.0, epsilon=0.2, kernel='poly', gamma='auto')
reg(model, X, Y)
# Out:
# RMSE Score is: 0.25642938781691366
# R2 Score is: 57.63498422841267
# Cross Validation Score: -57.40961002308778
# R2 Score - Cross Validation Score is 115.04459425150046

# %%
# Decision Tree Regressor

model=DecisionTreeRegressor(criterion="poisson", random_state=111)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.3417297329033748
# R2 Score is: 24.76198733643683
# Cross Validation Score: -147.89722260338294
# R2 Score - Cross Validation Score is 172.6592099398198

# %%
# Random Forest Regressor

model=RandomForestRegressor(max_depth=2, max_features="sqrt")
reg(model, X, Y)
# Out:
# RMSE Score is: 0.3021099079708912
# R2 Score is: 41.196697368958425
# Cross Validation Score: -14.434332197328658
# R2 Score - Cross Validation Score is 55.63102956628708

# %%
# K Neighbors Regressor

KNeighborsRegressor(n_neighbors=2, algorithm='kd_tree')
reg(model, X, Y)
# Out:
# RMSE Score is: 0.30083056249891554
# R2 Score is: 41.693671809117596
# Cross Validation Score: -24.136990664733656
# R2 Score - Cross Validation Score is 65.83066247385125

# %%
# Gradient Boosting Regressor

model=GradientBoostingRegressor(loss='quantile', n_estimators=200, max_depth=5)
reg(model, X, Y)
# Out:
# RMSE Score is: 0.27395585307232023
# R2 Score is: 51.64593961906559

# %%
# Ada Boost Regressor

model=AdaBoostRegressor(n_estimators=300, learning_rate=1.05, random_state=42)
reg(model, X, Y)

# %%
# Extra Trees Regressor

model=ExtraTreesRegressor(n_estimators=200, max_features='sqrt', n_jobs=6)
reg(model, X, Y)

# %%
# Choosing XGB Regressor

fmod_param = {'n_estimators' : [200, 400, 600],
              'gamma' : [2.0, 3.0, 4.0],
              'max_depth' : [4, 6, 8],
              'n_jobs' : [-2, -1, 1]
             }

# %%
gs_model.score(X_train,Y_train)

# %%
gs_model.score( X_test, Y_test )

# %%
import joblib
joblib.dump(gs_model,'price_model_reg.pkl')
